# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn import preprocessing as p

es = EarlyStopping(monitor = "val_loss", mode = "min", patience = 3)
EPOCHS = 100

df = pd.read_table('MatchTimelinesFirst15.csv', sep = ',')

# %%
df
# Out:
#        Unnamed: 0       matchId  blue_win  blueGold  blueMinionsKilled  \
# 0               0  3.493251e+09         0   24575.0              349.0
# 1               1  3.464936e+09         0   27210.0              290.0
# 2               2  3.428426e+09         1   32048.0              346.0
# 3               3  3.428347e+09         0   20261.0              223.0
# 4               4  3.428351e+09         1   30217.0              376.0
# ...           ...           ...       ...       ...                ...
# 48646       48646  3.475682e+09         0   27013.0              338.0
# 48647       48647  3.500988e+09         1   25376.0              350.0
# 48648       48648  3.496593e+09         0   25456.0              308.0
# 48649       48649  3.491706e+09         1   27033.0              335.0
# 48650       48650  3.478247e+09         0   23194.0              325.0
#
#        blueJungleMinionsKilled  blueAvgLevel  redGold  redMinionsKilled  \
# ...

# %%
variables = ['blueGold', 'blueMinionsKilled', 'blueJungleMinionsKilled', 'blueAvgLevel', 'blueChampKills', 'blueHeraldKills', 'blueTowersDestroyed']

stats_dict = {'Variable': variables, 'Mean': [], 'Std': [], 'Min': [], 'Mdn': [], 'Max': []}

for variable in variables:
    mean_value = df[variable].mean()
    std_value = df[variable].std()
    min_value = df[variable].min()
    median_value = df[variable].median()
    max_value = df[variable].max()

    stats_dict['Mean'].append(mean_value)
    stats_dict['Std'].append(std_value)
    stats_dict['Min'].append(min_value)
    stats_dict['Mdn'].append(median_value)
    stats_dict['Max'].append(max_value)

stats_df = pd.DataFrame(stats_dict)

print(stats_df)
# Out:
#                   Variable          Mean          Std      Min      Mdn  \
# 0                 blueGold  26349.160572  2777.299868  15930.0  26167.0
# 1        blueMinionsKilled    335.859140    32.673096    120.0    337.0
# 2  blueJungleMinionsKilled     83.136585    14.794947      0.0     83.0
# 3             blueAvgLevel      9.172251     0.413735      5.4      9.2
# 4           blueChampKills     11.013155     4.532898      0.0     11.0
# 5          blueHeraldKills      1.316355     0.956784      0.0      1.0
# 6      blueTowersDestroyed      0.794084     1.054556      0.0      1.0
#
#        Max
# 0  39769.0
# 1    455.0
# 2    164.0
# 3     10.8
# 4     50.0
# 5      4.0
# 6     11.0

# %%
latex_table = stats_df.to_latex(index=False, float_format="%.2f")

with open('table.tex', 'w') as f:
    f.write(latex_table)

# %%
df.describe()
# Out:
#         Unnamed: 0       matchId      blue_win      blueGold  \
# count  48651.00000  4.865100e+04  48651.000000  48651.000000
# mean   24325.00000  3.486083e+09      0.505416  26349.160572
# std    14044.47831  2.812307e+07      0.499976   2777.299868
# min        0.00000  2.544365e+09      0.000000  15930.000000
# 25%    12162.50000  3.475554e+09      0.000000  24401.500000
# 50%    24325.00000  3.494380e+09      1.000000  26167.000000
# 75%    36487.50000  3.506802e+09      1.000000  28126.000000
# max    48650.00000  3.513125e+09      1.000000  39769.000000
#
#        blueMinionsKilled  blueJungleMinionsKilled  blueAvgLevel       redGold  \
# count       48651.000000             48651.000000  48651.000000  48651.000000
# mean          335.859140                83.136585      9.172251  26203.028591
# std            32.673096                14.794947      0.413735   2754.709425
# min           120.000000                 0.000000      5.400000  11133.000000
# ...

# %%
df = df.drop([df.columns[0],'matchId','blueDragonKills','redDragonKills'], axis = 1)

# %%
df
# Out:
#        blue_win  blueGold  blueMinionsKilled  blueJungleMinionsKilled  \
# 0             0   24575.0              349.0                     89.0
# 1             0   27210.0              290.0                     36.0
# 2             1   32048.0              346.0                     92.0
# 3             0   20261.0              223.0                     60.0
# 4             1   30217.0              376.0                    110.0
# ...         ...       ...                ...                      ...
# 48646         0   27013.0              338.0                     61.0
# 48647         1   25376.0              350.0                     91.0
# 48648         0   25456.0              308.0                     92.0
# 48649         1   27033.0              335.0                     85.0
# 48650         0   23194.0              325.0                     81.0
#
#        blueAvgLevel  redGold  redMinionsKilled  redJungleMinionsKilled  \
# ...

# %%
cols_to_scale = ['blueGold','blueMinionsKilled','blueJungleMinionsKilled','blueAvgLevel','redGold','redMinionsKilled','redJungleMinionsKilled','redAvgLevel','blueChampKills','blueHeraldKills','blueTowersDestroyed','redChampKills','redHeraldKills','redTowersDestroyed']

scaler = p.StandardScaler().fit(df[cols_to_scale])

df[cols_to_scale] = scaler.transform(df[cols_to_scale])

# %%
df
# Out:
#        blue_win  blueGold  blueMinionsKilled  blueJungleMinionsKilled  \
# 0             0 -0.638814           0.402196                 0.396316
# 1             0  0.309959          -1.403589                -3.186025
# 2             1  2.051956           0.310377                 0.599090
# 3             0 -2.192137          -3.454227                -1.563833
# 4             1  1.392676           1.228573                 1.815734
# ...         ...       ...                ...                      ...
# 48646         0  0.239026           0.065524                -1.496241
# 48647         1 -0.350402           0.432803                 0.531499
# 48648         0 -0.321596          -0.852672                 0.599090
# 48649         1  0.246227          -0.026295                 0.125951
# 48650         0 -1.136065          -0.332361                -0.144415
#
#        blueAvgLevel   redGold  redMinionsKilled  redJungleMinionsKilled  \
# ...

# %%
X = df[['blueGold','blueMinionsKilled','blueJungleMinionsKilled','blueAvgLevel','redGold','redMinionsKilled','redJungleMinionsKilled','redAvgLevel','blueChampKills','blueHeraldKills','blueTowersDestroyed','redChampKills','redHeraldKills','redTowersDestroyed']]
y = df[['blue_win']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state=1)

# %%
x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
x_test = tf.convert_to_tensor(x_test, dtype=tf.float32)

# %%
num_train_samples = x_train.shape[0]
num_test_samples = x_test.shape[0]

print(f"Liczba obserwacji w zbiorze treningowym: {num_train_samples}")
print(f"Liczba obserwacji w zbiorze testowym: {num_test_samples}")
# Out:
# Liczba obserwacji w zbiorze treningowym: 38920
# Liczba obserwacji w zbiorze testowym: 9731

# %%
#NN najprostrzy model:

# %%
simple_model = Sequential()
simple_model.add(Dense(8, activation='relu', input_shape=(14,)))
simple_model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\Gracjan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
simple_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Gracjan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history_simple = simple_model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Gracjan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Gracjan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4813 - accuracy: 0.7589 - val_loss: 0.4491 - val_accuracy: 0.7811
# Epoch 2/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4466 - accuracy: 0.7844 - val_loss: 0.4460 - val_accuracy: 0.7840
# Epoch 3/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4440 - accuracy: 0.7864 - val_loss: 0.4452 - val_accuracy: 0.7842
# Epoch 4/10
# ...

# %%
accuracy1 = history_simple.history['accuracy'][-1]

# %%
#Model 2 - więcej neuronów warstwy ukrytej

# %%
model2 = Sequential()
model2.add(Dense(32, activation='relu'))  
model2.add(Dense(16, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history2 = model2.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4555 - accuracy: 0.7791 - val_loss: 0.4439 - val_accuracy: 0.7872
# Epoch 2/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4426 - accuracy: 0.7866 - val_loss: 0.4454 - val_accuracy: 0.7847
# Epoch 3/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4417 - accuracy: 0.7867 - val_loss: 0.4449 - val_accuracy: 0.7856
# Epoch 4/10
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4410 - accuracy: 0.7879 - val_loss: 0.4434 - val_accuracy: 0.7855
# Epoch 5/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4401 - accuracy: 0.7888 - val_loss: 0.4439 - val_accuracy: 0.7830
# Epoch 6/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4398 - accuracy: 0.7897 - val_loss: 0.4434 - val_accuracy: 0.7857
# Epoch 7/10
# ...

# %%
accuracy2 = history2.history['accuracy'][-1]

# %%
#Model 3 - mniej neuronów warstwy ukrytej

# %%
model = Sequential()
model.add(Dense(8, activation='relu'))  
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4718 - accuracy: 0.7758 - val_loss: 0.4469 - val_accuracy: 0.7836
# Epoch 2/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4455 - accuracy: 0.7848 - val_loss: 0.4447 - val_accuracy: 0.7858
# Epoch 3/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4434 - accuracy: 0.7862 - val_loss: 0.4439 - val_accuracy: 0.7871
# Epoch 4/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4427 - accuracy: 0.7848 - val_loss: 0.4436 - val_accuracy: 0.7880
# Epoch 5/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4421 - accuracy: 0.7857 - val_loss: 0.4442 - val_accuracy: 0.7887
# Epoch 6/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4418 - accuracy: 0.7864 - val_loss: 0.4436 - val_accuracy: 0.7888
# Epoch 7/10
# ...

# %%
accuracy3 = history.history['accuracy'][-1]

# %%
#Model 4 - dodatkowa warstwa ukryta

# %%
model = Sequential()
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu')) 
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4660 - accuracy: 0.7727 - val_loss: 0.4480 - val_accuracy: 0.7852
# Epoch 2/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4437 - accuracy: 0.7844 - val_loss: 0.4453 - val_accuracy: 0.7871
# Epoch 3/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4424 - accuracy: 0.7856 - val_loss: 0.4452 - val_accuracy: 0.7863
# Epoch 4/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4416 - accuracy: 0.7867 - val_loss: 0.4446 - val_accuracy: 0.7857
# Epoch 5/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4411 - accuracy: 0.7872 - val_loss: 0.4443 - val_accuracy: 0.7874
# Epoch 6/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4406 - accuracy: 0.7880 - val_loss: 0.4444 - val_accuracy: 0.7871
# Epoch 7/10
# ...

# %%
accuracy4 = history.history['accuracy'][-1]

# %%
#Model 5 - Inny współczynnik uczenia

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(14,)))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4801 - accuracy: 0.7614 - val_loss: 0.4487 - val_accuracy: 0.7813
# Epoch 2/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4464 - accuracy: 0.7847 - val_loss: 0.4452 - val_accuracy: 0.7844
# Epoch 3/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4440 - accuracy: 0.7859 - val_loss: 0.4450 - val_accuracy: 0.7855
# Epoch 4/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4431 - accuracy: 0.7865 - val_loss: 0.4444 - val_accuracy: 0.7854
# Epoch 5/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4424 - accuracy: 0.7867 - val_loss: 0.4446 - val_accuracy: 0.7851
# Epoch 6/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4421 - accuracy: 0.7870 - val_loss: 0.4441 - val_accuracy: 0.7849
# Epoch 7/10
# ...

# %%
accuracy5 = history.history['accuracy'][-1]

# %%
#Model 6 - Inna funkcja aktywacji

# %%
model = Sequential()
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4759 - accuracy: 0.7737 - val_loss: 0.4557 - val_accuracy: 0.7868
# Epoch 2/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4511 - accuracy: 0.7855 - val_loss: 0.4515 - val_accuracy: 0.7889
# Epoch 3/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4478 - accuracy: 0.7859 - val_loss: 0.4493 - val_accuracy: 0.7870
# Epoch 4/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4459 - accuracy: 0.7874 - val_loss: 0.4481 - val_accuracy: 0.7879
# Epoch 5/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4446 - accuracy: 0.7871 - val_loss: 0.4476 - val_accuracy: 0.7866
# Epoch 6/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4437 - accuracy: 0.7875 - val_loss: 0.4474 - val_accuracy: 0.7861
# Epoch 7/10
# ...

# %%
accuracy6 = history.history['accuracy'][-1]

# %%
#Model 7 - Inny batch size

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(14,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), batch_size=64)
# Out:
# Epoch 1/10
# 609/609 [==============================] - 2s 2ms/step - loss: 0.4907 - accuracy: 0.7525 - val_loss: 0.4520 - val_accuracy: 0.7833
# Epoch 2/10
# 609/609 [==============================] - 1s 2ms/step - loss: 0.4471 - accuracy: 0.7829 - val_loss: 0.4469 - val_accuracy: 0.7858
# Epoch 3/10
# 609/609 [==============================] - 1s 2ms/step - loss: 0.4443 - accuracy: 0.7849 - val_loss: 0.4453 - val_accuracy: 0.7869
# Epoch 4/10
# 609/609 [==============================] - 1s 2ms/step - loss: 0.4430 - accuracy: 0.7852 - val_loss: 0.4447 - val_accuracy: 0.7870
# Epoch 5/10
# 609/609 [==============================] - 1s 2ms/step - loss: 0.4424 - accuracy: 0.7861 - val_loss: 0.4444 - val_accuracy: 0.7858
# Epoch 6/10
# 609/609 [==============================] - 1s 2ms/step - loss: 0.4419 - accuracy: 0.7867 - val_loss: 0.4441 - val_accuracy: 0.7851
# Epoch 7/10
# ...

# %%
accuracy7 = history.history['accuracy'][-1]

# %%
#Model 8 - Inna liczba epok

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(14,)))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.5103 - accuracy: 0.7393 - val_loss: 0.4560 - val_accuracy: 0.7797
# Epoch 2/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4490 - accuracy: 0.7819 - val_loss: 0.4502 - val_accuracy: 0.7837
# Epoch 3/20
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.4455 - accuracy: 0.7845 - val_loss: 0.4480 - val_accuracy: 0.7852
# Epoch 4/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4438 - accuracy: 0.7850 - val_loss: 0.4472 - val_accuracy: 0.7848
# Epoch 5/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4429 - accuracy: 0.7863 - val_loss: 0.4467 - val_accuracy: 0.7849
# Epoch 6/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4422 - accuracy: 0.7870 - val_loss: 0.4455 - val_accuracy: 0.7881
# Epoch 7/20
# ...

# %%
accuracy8 = history.history['accuracy'][-1]

# %%
#Model 9 - warstwy dropout:

# %%
model = Sequential()
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2)) 
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4965 - accuracy: 0.7518 - val_loss: 0.4484 - val_accuracy: 0.7813
# Epoch 2/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4522 - accuracy: 0.7843 - val_loss: 0.4459 - val_accuracy: 0.7839
# Epoch 3/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4499 - accuracy: 0.7852 - val_loss: 0.4453 - val_accuracy: 0.7848
# Epoch 4/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4470 - accuracy: 0.7857 - val_loss: 0.4449 - val_accuracy: 0.7842
# Epoch 5/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4466 - accuracy: 0.7864 - val_loss: 0.4460 - val_accuracy: 0.7860
# Epoch 6/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4459 - accuracy: 0.7862 - val_loss: 0.4447 - val_accuracy: 0.7850
# Epoch 7/10
# ...

# %%
accuracy9 = history.history['accuracy'][-1]

# %%
#Model 10 - inna funkcja straty:

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(14,)))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.1554 - accuracy: 0.7704 - val_loss: 0.1482 - val_accuracy: 0.7820
# Epoch 2/10
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.1467 - accuracy: 0.7853 - val_loss: 0.1467 - val_accuracy: 0.7861
# Epoch 3/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.1457 - accuracy: 0.7858 - val_loss: 0.1462 - val_accuracy: 0.7863
# Epoch 4/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.1453 - accuracy: 0.7861 - val_loss: 0.1459 - val_accuracy: 0.7865
# Epoch 5/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.1450 - accuracy: 0.7867 - val_loss: 0.1458 - val_accuracy: 0.7874
# Epoch 6/10
# 1217/1217 [==============================] - 2s 1ms/step - loss: 0.1449 - accuracy: 0.7872 - val_loss: 0.1458 - val_accuracy: 0.7885
# Epoch 7/10
# ...

# %%
accuracy10 = history.history['accuracy'][-1]

# %%
accuracies = [accuracy1, accuracy2, accuracy3, accuracy4, accuracy5, accuracy6, accuracy7, accuracy8, accuracy9, accuracy10]
models = ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5', 'Model 6', 'Model 7', 'Model 8', 'Model 9', 'Model 10']

colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown', 'pink', 'gray', 'cyan', 'magenta']

fig, ax = plt.subplots(figsize=(10, 6)) 
bars = plt.bar(models, accuracies, color=colors)

plt.ylabel('Accuracy')
plt.title('Porównanie Accuracy dla różnych modeli')

plt.ylim(0.78, 0.8)

for bar, accuracy in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.0005, f'{accuracy:.4f}', ha='center')

plt.subplots_adjust(bottom=0.15)

plt.show()

# %%
#Dwa potężne modele

# %%
model1 = Sequential()
model1.add(Dense(32, activation='relu', input_shape=(x_train.shape[1],)))
model1.add(Dense(16, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

# Kompilacja modelu
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history1 = model1.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4528 - accuracy: 0.7788 - val_loss: 0.4450 - val_accuracy: 0.7845
# Epoch 2/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4430 - accuracy: 0.7867 - val_loss: 0.4448 - val_accuracy: 0.7856
# Epoch 3/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4415 - accuracy: 0.7879 - val_loss: 0.4448 - val_accuracy: 0.7857
# Epoch 4/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4406 - accuracy: 0.7885 - val_loss: 0.4451 - val_accuracy: 0.7853
# Epoch 5/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4402 - accuracy: 0.7895 - val_loss: 0.4438 - val_accuracy: 0.7859
# Epoch 6/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4395 - accuracy: 0.7906 - val_loss: 0.4448 - val_accuracy: 0.7866
# Epoch 7/50
# ...

# %%
accuracy11 = history1.history['accuracy'][-1]

# %%
model2 = Sequential()
model2.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

# Kompilacja modelu
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history2 = model2.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 1217/1217 [==============================] - 3s 2ms/step - loss: 0.4492 - accuracy: 0.7834 - val_loss: 0.4462 - val_accuracy: 0.7861
# Epoch 2/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4428 - accuracy: 0.7857 - val_loss: 0.4447 - val_accuracy: 0.7867
# Epoch 3/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4414 - accuracy: 0.7869 - val_loss: 0.4446 - val_accuracy: 0.7860
# Epoch 4/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4410 - accuracy: 0.7884 - val_loss: 0.4443 - val_accuracy: 0.7874
# Epoch 5/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4398 - accuracy: 0.7900 - val_loss: 0.4455 - val_accuracy: 0.7871
# Epoch 6/50
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4387 - accuracy: 0.7911 - val_loss: 0.4447 - val_accuracy: 0.7864
# Epoch 7/50
# ...

# %%
accuracy12 = history2.history['accuracy'][-1]

# %%
#NN model X:

# %%
model = Sequential()
model.add(Dense(16, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss = "binary_crossentropy", optimizer = 'adam', metrics=["accuracy"])

# %%
EPOCHS = 20

# %%
history3=model.fit(x_train, y_train, epochs = EPOCHS, validation_data = (x_test, y_test))
# Out:
# Epoch 1/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4390 - accuracy: 0.7902 - val_loss: 0.4441 - val_accuracy: 0.7864
# Epoch 2/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4387 - accuracy: 0.7914 - val_loss: 0.4442 - val_accuracy: 0.7864
# Epoch 3/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4387 - accuracy: 0.7909 - val_loss: 0.4439 - val_accuracy: 0.7847
# Epoch 4/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4387 - accuracy: 0.7902 - val_loss: 0.4438 - val_accuracy: 0.7863
# Epoch 5/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4385 - accuracy: 0.7904 - val_loss: 0.4443 - val_accuracy: 0.7864
# Epoch 6/20
# 1217/1217 [==============================] - 2s 2ms/step - loss: 0.4384 - accuracy: 0.7913 - val_loss: 0.4440 - val_accuracy: 0.7849
# Epoch 7/20
# ...

# %%
accuracy13 = history3.history['accuracy'][-1]

# %%
#history=  model.fit(x_train, y_train, epochs = EPOCHS, validation_data = (x_test, y_test) , callbacks = [es])

# %%
hist = pd.DataFrame(history3.history)
plt.plot(hist.loss, label = "loss")
plt.plot(hist.val_loss, label = "val_loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()

# %%
import matplotlib.pyplot as plt

models = ["Model 11", "Model 12", "Model 13"]
accuracies = [accuracy11, accuracy12, accuracy13]

colors = ['blue', 'orange', 'green']  

plt.bar(models, accuracies, color=colors)
plt.ylim(0.78, 0.80) 
plt.xlabel('')
plt.ylabel('Accuracy')

for i, accuracy in enumerate(accuracies):
    plt.text(i, accuracy + 0.002, f'{accuracy:.4f}', ha='center', va='bottom')

plt.show()

# %%
accuracies = [accuracy1, accuracy2, accuracy3, accuracy4, accuracy5, accuracy6, accuracy7, accuracy8, accuracy9, accuracy10, accuracy11, accuracy12, accuracy13]
models = ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5', 'Model 6', 'Model 7', 'Model 8', 'Model 9', 'Model 10', 'Model 11', 'Model 12', 'Model 13']

colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown', 'pink', 'gray', 'cyan', 'magenta', 'blue', 'orange', 'green']

fig, ax = plt.subplots(figsize=(13, 6)) 
bars = plt.bar(models, accuracies, color=colors)

plt.ylabel('Accuracy')


plt.ylim(0.78, 0.8)

for bar, accuracy in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.0005, f'{accuracy:.4f}', ha='center')

plt.subplots_adjust(bottom=0.15)

plt.show()
